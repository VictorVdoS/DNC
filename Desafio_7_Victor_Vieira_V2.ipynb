# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorVdoS/DNC/blob/main/Desafio_7_Victor_Vieira_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Desafio 7: Crie um modelo de análise das métricas RFV

# %% [markdown]
# ###Autor: [Victor Vieira dos Santos](https://github.com/VictorVdoS)

# %% [markdown]
# #📎 Arquivo do Desafio:
# https://www.notion.so/signed/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fe73c934e-cd3a-4e00-85f6-b704762fec77%2Fdata.csv?table=block&id=e9f1a77d-e0db-46c4-8ef0-c79064da3c0e&spaceId=6a055055-52ec-4ebb-a697-63027c951344&userId=c0845f00-59fb-4a0f-bb4a-c1e2314cd202&cache=v2
#
# [ChatGPT](https://chat.openai.com/): Pode ser útil para iniciar sua pesquisa!
#
# [Python Graph Gallery](https://python-graph-gallery.com/): repositório com o passo a passo de como gerar gráficos utilizando as principais bibliotecas de Python
#
# [SciKit Learn](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning): documentação com os principais modelos utilizados para classificação

# %% [markdown]
# ##Elabore um modelo de Clustering
# Você deverá utilizar um modelo de Clustering para criar um sistema
# de agrupamento de perfis de clientes para um e-commerce. Deverá
# analisar o modelo mais eficiente, capaz de tornar as análises mais
# simplificadas para a empresa.

# %% [markdown]
# ##Contexto
# Você foi contratado por uma empresa de e-commerce que está buscando entender
# melhor o comportamento de seus clientes para personalizar as suas campanhas de
# marketing. Para isso, a empresa disponibilizou uma base de dados em csv contendo
# dados sobre clientes, produtos e transações da loja realizadas entre os anos de 2010 e
# 2011.
# Com base nesses dados, você precisa agrupar os clientes em clusters com base em
# seu comportamento de compra. Isso irá permitir identificar padrões e características em
# comum entre os clientes, como:
# Clientes que compram os mesmos produtos;
# Clientes que possuem a mesma frequência de compras;
# Clientes que gastam mais dinheiro em suas compras.
# A partir desses clusters, gere insights para que a empresa possa segmentar melhor a
# sua base de clientes e personalizar as suas campanhas de marketing, direcionando
# promoções e ofertas aos clientes com base no comportamento de compras.

# %% [markdown]
# ##Sobre os dados
# Acesse os dados aqui: https://www.kaggle.com/datasets/carrie1/ecommerce-data
# Os dados fornecidos possuem informações de transações de compras de uma loja de
# e-commerce em 38 países e territórios, com mais de 4.000 clientes únicos e mais de
# 540.000 transações.
# Atenção: as datas estão no formato MM/DD/YYYY HH:mm:ss; existem dados nulos que
# precisam ser tratados antes da realização da análise; por mais que os códigos de
# identificação sejam numéricos, o modelo não pode considerá-los como grandezas
# numéricas.
#
# Coluna Descrição Tipo
# InvoiceNo Identificação da transação Int
# StockCode Código de estoque do produto String
# Description Descrição do produto String
# Quantity Quantidade de produtos por transação Int
# InvoiceDate Data da transação Datetime
# UnitPrice Preço unitário do produto Float
# CustomerID Identificação do cliente Int
# Country País de origem da transação String

# %% [markdown]
# ##Como começar?
# Desenvolva um modelo de clusterização que seja capaz de agrupar os clientes
# conforme o seu comportamento de compras levando em consideração o RFM
# calculado no desafio 4.
# Analise os clusters obtidos para identificar o perfil de cliente, como padrões e
# características em comum para determinar o seu comportamento de compra. Utilize
# gráficos e visualizações para auxiliar na análise.
# Não se esqueça de documentar cada etapa, justificando as escolhas realizadas. É
# essencial informar os insights obtidos e as recomendações de ações futuras para que a
# empresa possa colocá-los em prática. Boa sorte!

# %% [markdown]
# #🎯 Etapas de Desenvolvimento

# %% [markdown]
# ##Etapa 01) Análise exploratória dos dados
# a. Carregue a base de dados;
# b. Realize uma descrição estatística dos dados;
# c. Visualize as distribuições e identifique a relevância das colunas para a análise;
# d. Verifique a presença de dados nulos, duplicados, outliers e demais inconsistências
# nos dados.
#
# 💡 Dica: certifique-se de que os dados estejam no formato ideal para as
# análises; por mais que os códigos de identificação sejam numéricos, sua
# análise não pode considerá-los como grandezas numéricas.

# %% [markdown]
# ##Etapa 02) Pré-processamento dos dados
# a. Realize a normalização dos dados
# b. Faça uma seleção das variáveis mais relevantes para o modelo;
# c. Remova os dados nulos, duplicados, outliers e inconsistentes

# %% [markdown]
# ##Etapa 03) Selecione um algoritmo de clusterização
# a. Escolha um algoritmo adequado para base de dados, como o K0Means, DBSCAN,
# Hierarquia ou Mean Shift
# b. Encontre a quantidade ideal de clusters através dos métodos de Elbow ou
# Silhouette Score
# c. Implemente o algoritmo escolhido

# %% [markdown]
# ##Etapa 04) Analise os clusters obtidos
# a. Identifique os padrões e características em comum entre os clientes
# b. Plote gráficos para auxiliar na análise

# %% [markdown]
# ##Etapa 05) Interpretação dos resultados obtidos
# a. Descreva o perfil de compras dos clientes de cada cluster
# b. Justifique como essa análise pode ser útil para empresa para segmentação de
# seus clientes e personalização das campanhas de marketing
# c. Sugira ações possíveis com base nas ações realizadas

# %% [markdown]
# #📝 Critérios de Avaliação
# Desafio: Crie um modelo de análise das métricas RFV 5
# Os critérios de avaliação mostram como você será avaliado em relação ao seu desafio.
# Critérios Atendeu às Especificações Pontos
# Organização e
# legibilidade do
# código
# O código precisa estar organizado de forma clara e
# legível, com comentários que expliquem as ações
# tomadas e divisão em sessões. Essa é a
# documentação do projeto apresentado para o cliente.
# 20
# Justificativa das
# tomadas de
# decisão
# É importante que as decisões tomadas durante todo o
# processo de análise sejam devidamente justificadas,
# desde a escolha das variáveis até a escolha do
# algoritmo de clusterização.
# 20
# Qualidade da
# análise
# exploratória
# A análise deve ser completa e detalhada, mostrando a
# relação entre as variáveis e possíveis insights
# encontrados.
# 20
# Qualidade da
# análise dos
# clusters
# Os clusters devem ser bem definidos e interpretáveis,
# identificando suas características que os definem.
# 20
# Apresentação de
# proposta coerente
# com os clusters
# encontrados
# A proposta deve ser coerente com os clusters
# encontrados, sugerindo ações que possam ser
# tomadas para melhorar o desempenho do e-commerce
# com base nas suas características.
# 20

# %% [markdown]
# #📆 Entrega
# 📎 Como entregar: Você deverá submeter o link compartilhável do colab!
# Evite sequências longas de código sem explicação do que está sendo realizado.
# 💡 Dica: pense que essa documentação está sendo apresentada para o cliente
# final, seu modelo não pode ser uma “caixa preta”.

# %% [markdown]
# #Etapa 01) Análise exploratória dos dados

# %%
#Instalando bibliotecas
#!pip install yellowbrick
#!pip install numpy pandas seaborn matplotlib plotly scikit-learn yellowbrick tabulate

# %%
#Importando Bibliotecas
#Ignora warnings
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colors as mcolors
from scipy.stats import linregress
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.cluster import KMeans
from tabulate import tabulate
from collections import Counter

# %%
# %matplotlib inline
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Carregar a base
df = pd.read_csv('/content/data.csv', sep=',' ,encoding = 'ISO-8859-1')

# %%
#Data Understanding
print('\n' + '-' * 22 + 'Dataset' + '-' * 22)
display(df.head())
print('\n' + '-' * 22 + 'Data Shape' + '-' * 22)
display(df.shape)
print('\n' + '-' * 22 + 'Data Info' + '-' * 22)
display(df.info())
print('\n' + '-' * 22 + 'Data Describe' + '-' * 22)
display(df.describe().T.round(2))
print('\n' + '-' * 22 + 'Data Describe' + '-' * 22)
display(df.describe(include = 'object').T)
print('\n' + '-' * 22 + 'Data Duplicated' + '-' * 22)
print('Duplicated entries: {}'.format(df.duplicated().sum()))
print('\n' + '-' * 22 + 'Data Null' + '-' * 22)
display(df.isna().sum().sort_values(ascending=False))
# Out:
# ----------------------Dataset----------------------
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ----------------------Data Shape----------------------
# (541909, 8)
# ----------------------Data Info----------------------
# ...

# %% [markdown]
# #Etapa 02) Pré-processamento dos dados

# %%
#Valores nulos
missing_values = df.isnull().sum()
missing_values
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Valores nulos em %
missing_percentage = (missing_values[missing_values>0] / df.shape[0]) * 100
missing_percentage
# Out:
# Description     0.268311
# CustomerID     24.926694
# dtype: float64

# %%
#Grafico de valores faltantes
fig, ax = plt.subplots(figsize=(15, 4))
ax.barh(missing_percentage.index, missing_percentage, color='blue')


for i, (value, name) in enumerate(zip(missing_percentage, missing_percentage.index)):
    ax.text(value+0.5, i, f'{value:.2f}%', ha='left', va='center', fontweight='bold', fontsize=18, color='red')

ax.set_xlim([0, 40])

plt.title('Porcentagem de valores faltantes', fontweight='bold', fontsize=22)
plt.xlabel('Porcentagem (%)', fontsize=16)
plt.show()

# %%
#Remove nulos
df.drop_duplicates(inplace=True)

# %%
#Remove duplicados
duplicate_rows = df[df.duplicated(keep=False)]

if duplicate_rows.empty:
    print('Nenhuma linha duplicada encontrada.')
else:
    print('Linhas duplicadas encontradas.')
# Out:
# Nenhuma linha duplicada encontrada.

# %%
print(df['Quantity'].min())
print(df['UnitPrice'].min())
# Out:
# -80995
# -11062.06

# %%
df = df.loc[df['Quantity'] >0 ]
print(df['Quantity'].min())
# Out:
# 1

# %%
#Stock unicos
unique_stock_codes = df['StockCode'].nunique()
unique_stock_codes
# Out:
# 3941

# %%
#Top 10 stock
top_10_stock_codes = df['StockCode'].value_counts(normalize=True).head(10) * 100
top_10_stock_codes
# Out:
# 85123A    0.429234
# 85099B    0.401480
# 22423     0.381900
# 47566     0.323161
# 20725     0.300730
# 84879     0.280580
# 22197     0.269554
# 22720     0.264992
# 21212     0.257008
# 22383     0.248454
# Name: StockCode, dtype: float64

# %%
#Plot top 10 stock codes mais frequentes
plt.figure(figsize=(12, 5))
top_10_stock_codes.plot(kind='barh', color='blue')

#Adicionando a porcentagem no gráfico
for index, value in enumerate(top_10_stock_codes):
    plt.text(value, index+.25, f'{value:.2f}%', fontsize=10)

plt.title('top 10 Stock Codes mais requentes')
plt.xlabel('Frequencia em (%)')
plt.ylabel('Stock Codes')
plt.gca().invert_yaxis()
plt.show()

# %%
unique_stock_codes = df['StockCode'].unique()
unique_stock_codes
# Out:
# array(['85123A', '71053', '84406B', ..., '90214U', '47591b', '23843'],
#       dtype=object)

# %%
numeric_char_counts_in_unique_codes = pd.Series(unique_stock_codes).apply(lambda x: sum(c.isdigit() for c in str(x))).value_counts()
numeric_char_counts_in_unique_codes
# Out:
# 5    3919
# 0      11
# 4       5
# 6       5
# 1       1
# dtype: int64

# %%
anomalous_stock_codes = [code for code in unique_stock_codes if sum(c.isdigit() for c in str(code)) in (0, 1)]

#Print stock code em linha
print('Stock codes anômalos:')
print('-'*22)
for code in anomalous_stock_codes:
    print(code)
# Out:
# Stock codes anômalos:
# ----------------------
# POST
# C2
# DOT
# M
# BANK CHARGES
# AMAZONFEE
# m
# DCGSSBOY
# DCGSSGIRL
# S
# PADS
# B

# %%
#Calculando a porcentagem de registros com códigos anômalos
percentage_anomalous = (df['StockCode'].isin(anomalous_stock_codes).sum() / len(df)) * 100
print(f'{percentage_anomalous:.2f}%')
# Out:
# 0.45%

# %%
df = df[~df['StockCode'].isin(anomalous_stock_codes)]

# %%
df.shape[0]
# Out:
# 523703

# %%
df['UnitPrice'].describe()
# Out:
# count    523703.000000
# mean          3.267827
# std           4.393995
# min           0.000000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max         649.500000
# Name: UnitPrice, dtype: float64

# %%
df[df['UnitPrice']==0].describe()[['Quantity']]
# Out:
#            Quantity
# count   1159.000000
# mean      58.747196
# std      454.177984
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       20.000000
# max    12540.000000

# %%
#Removendo registros comm preço menor que 0
df = df[df['UnitPrice'] > 0]

# %%
df.shape[0]
# Out:
# 522544

# %%
#Reset index
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##RFM Features

# %%
#Convertendo InvoiceDate em datetime type
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

#Convertendo InvoiceDate em datetime type e extraindo apenas a data
df['InvoiceDay'] = df['InvoiceDate'].dt.date

# %%
#Encontrada a compra mais recente por usuário
customer_data = df.groupby('CustomerID')['InvoiceDay'].max().reset_index()


#Encontrando a compra mais recente
most_recent_date = df['InvoiceDay'].max()

#Convertendo InvoiceDay em datetime type depois da extração
customer_data['InvoiceDay'] = pd.to_datetime(customer_data['InvoiceDay'])
most_recent_date = pd.to_datetime(most_recent_date)

#Calculando a quantidade de dias depois da ultima compra
customer_data['Days_Since_Last_Purchase'] = (most_recent_date - customer_data['InvoiceDay']).dt.days

#Removendo a InvoiceDay column
customer_data.drop(columns=['InvoiceDay'], inplace=True)

# %%
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase
# 0     12346.0                       325
# 1     12347.0                         2
# 2     12348.0                        75
# 3     12349.0                        18
# 4     12350.0                       310

# %%
#Total de transações por usuários
total_transactions = df.groupby('CustomerID')['InvoiceNo'].nunique().reset_index()
total_transactions.rename(columns={'InvoiceNo': 'Total_Transactions'}, inplace=True)

#Total de produtos comprados por usuários
total_products_purchased = df.groupby('CustomerID')['Quantity'].sum().reset_index()
total_products_purchased.rename(columns={'Quantity': 'Total_Products_Purchased'}, inplace=True)

#Mesclar os novos recursos no dataframe customer_data
customer_data = pd.merge(customer_data, total_transactions, on='CustomerID')
customer_data = pd.merge(customer_data, total_products_purchased, on='CustomerID')

#Exibir as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12346.0                       325                   1
# 1     12347.0                         2                   7
# 2     12348.0                        75                   4
# 3     12349.0                        18                   1
# 4     12350.0                       310                   1
#
#    Total_Products_Purchased
# 0                     74215
# 1                      2458
# 2                      2332
# 3                       630
# 4                       196

# %%
#Calcule o gasto total de cada cliente
df['Total_Spend'] = df['UnitPrice'] * df['Quantity']
total_spend = df.groupby('CustomerID')['Total_Spend'].sum().reset_index()

#Calcule o valor médio da transação para cada cliente
average_transaction_value = total_spend.merge(total_transactions, on='CustomerID')
average_transaction_value['Average_Transaction_Value'] = average_transaction_value['Total_Spend'] / average_transaction_value['Total_Transactions']

#Mesclar os novos recursos no dataframe customer_data
customer_data = pd.merge(customer_data, total_spend, on='CustomerID')
customer_data = pd.merge(customer_data, average_transaction_value[['CustomerID', 'Average_Transaction_Value']], on='CustomerID')

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12346.0                       325                   1
# 1     12347.0                         2                   7
# 2     12348.0                        75                   4
# 3     12349.0                        18                   1
# 4     12350.0                       310                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value
# 0                     74215     77183.60               77183.600000
# 1                      2458      4310.00                 615.714286
# 2                      2332      1437.24                 359.310000
# 3                       630      1457.55                1457.550000
# 4                       196       294.40                 294.400000

# %%
#Calcule o número de produtos exclusivos adquiridos por cada cliente
unique_products_purchased = df.groupby('CustomerID')['StockCode'].nunique().reset_index()
unique_products_purchased.rename(columns={'StockCode': 'Unique_Products_Purchased'}, inplace=True)

#Mesclar o novo recurso no dataframe customer_data
customer_data = pd.merge(customer_data, unique_products_purchased, on='CustomerID')

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12346.0                       325                   1
# 1     12347.0                         2                   7
# 2     12348.0                        75                   4
# 3     12349.0                        18                   1
# 4     12350.0                       310                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                     74215     77183.60               77183.600000
# 1                      2458      4310.00                 615.714286
# 2                      2332      1437.24                 359.310000
# 3                       630      1457.55                1457.550000
# 4                       196       294.40                 294.400000
#
#    Unique_Products_Purchased
# 0                          1
# 1                        103
# 2                         21
# 3                         72
# 4                         16

# %%
#Extrair dia da semana e hora de InvoiceDate
df['Day_Of_Week'] = df['InvoiceDate'].dt.dayofweek
df['Hour'] = df['InvoiceDate'].dt.hour

#Calcule o número médio de dias entre compras consecutivas
days_between_purchases = df.groupby('CustomerID')['InvoiceDay'].apply(lambda x: (x.diff().dropna()).apply(lambda y: y.days))
average_days_between_purchases = days_between_purchases.groupby('CustomerID').mean().reset_index()
average_days_between_purchases.rename(columns={'InvoiceDay': 'Average_Days_Between_Purchases'}, inplace=True)


#Encontre o dia de compras favorito da semana
favorite_shopping_day = df.groupby(['CustomerID', 'Day_Of_Week']).size().reset_index(name='Count')
favorite_shopping_day = favorite_shopping_day.loc[favorite_shopping_day.groupby('CustomerID')['Count'].idxmax()][['CustomerID', 'Day_Of_Week']]


#Encontre o horário de compras favorito do dia
favorite_shopping_hour = df.groupby(['CustomerID', 'Hour']).size().reset_index(name='Count')
favorite_shopping_hour = favorite_shopping_hour.loc[favorite_shopping_hour.groupby('CustomerID')['Count'].idxmax()][['CustomerID', 'Hour']]

#Mesclar os novos recursos no dataframe customer_data
customer_data = pd.merge(customer_data, average_days_between_purchases, on='CustomerID')
customer_data = pd.merge(customer_data, favorite_shopping_day, on='CustomerID')
customer_data = pd.merge(customer_data, favorite_shopping_hour, on='CustomerID')

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12347.0                         2                   7
# 1     12348.0                        75                   4
# 2     12349.0                        18                   1
# 3     12350.0                       310                   1
# 4     12352.0                        36                   7
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458      4310.00                 615.714286
# 1                      2332      1437.24                 359.310000
# 2                       630      1457.55                1457.550000
# 3                       196       294.40                 294.400000
# 4                       526      1385.74                 197.962857
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                        103                        2.016575            1
# ...

# %%
df['Country'].value_counts(normalize=True).head()
# Out:
# United Kingdom    0.916436
# Germany           0.016540
# France            0.015472
# EIRE              0.014866
# Spain             0.004625
# Name: Country, dtype: float64

# %%
#Group by CustomerID e Country para obter o número de transações por país para cada cliente
customer_country = df.groupby(['CustomerID', 'Country']).size().reset_index(name='Number_of_Transactions')

#Obtenha o país com o número máximo de transações para cada cliente (caso um cliente tenha transações de vários países)
customer_main_country = customer_country.sort_values('Number_of_Transactions', ascending=False).drop_duplicates('CustomerID')

#Crie uma coluna binária indicando se o cliente é do Reino Unido ou não
customer_main_country['Is_UK'] = customer_main_country['Country'].apply(lambda x: 1 if x == 'United Kingdom' else 0)

#Mesclar esses dados com nosso dataframe customer_data
customer_data = pd.merge(customer_data, customer_main_country[['CustomerID', 'Is_UK']], on='CustomerID', how='left')

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12347.0                         2                   7
# 1     12348.0                        75                   4
# 2     12349.0                        18                   1
# 3     12350.0                       310                   1
# 4     12352.0                        36                   7
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458      4310.00                 615.714286
# 1                      2332      1437.24                 359.310000
# 2                       630      1457.55                1457.550000
# 3                       196       294.40                 294.400000
# 4                       526      1385.74                 197.962857
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                        103                        2.016575            1
# ...

# %%
#Exibir distribuição de recursos
customer_data['Is_UK'].value_counts()
# Out:
# 1    3847
# 0     414
# Name: Is_UK, dtype: int64

# %%
#Extrair mês e ano de InvoiceDate
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month

#Calcule os gastos mensais de cada cliente
monthly_spending = df.groupby(['CustomerID', 'Year', 'Month'])['Total_Spend'].sum().reset_index()

#Calcule padrões de compra sazonais: estamos usando a frequência mensal como um proxy para padrões de compra sazonais
seasonal_buying_patterns = monthly_spending.groupby('CustomerID')['Total_Spend'].agg(['mean', 'std']).reset_index()
seasonal_buying_patterns.rename(columns={'mean': 'Monthly_Spending_Mean', 'std': 'Monthly_Spending_Std'}, inplace=True)

#Substitua os valores NaN em Monthly_Spending_Std por 0, implicando nenhuma variabilidade para clientes com um único mês de transação
seasonal_buying_patterns['Monthly_Spending_Std'].fillna(0, inplace=True)

#Calcule tendências em gastos
#Estamos usando a inclinação da linha de tendência linear ajustada aos gastos do cliente ao longo do tempo como um indicador das tendências de gastos
def calculate_trend(spend_data):
#Se houver mais de um ponto de dados, calculamos a tendência usando regressão linear
    if len(spend_data) > 1:
        x = np.arange(len(spend_data))
        slope, _, _, _, _ = linregress(x, spend_data)
        return slope
#Se houver apenas um ponto de dados, nenhuma tendência poderá ser calculada, portanto retornamos 0
    else:
        return 0

#Aplique a função calcula_trend para encontrar a tendência de gastos de cada cliente
spending_trends = monthly_spending.groupby('CustomerID')['Total_Spend'].apply(calculate_trend).reset_index()
spending_trends.rename(columns={'Total_Spend': 'Spending_Trend'}, inplace=True)

#Mesclar os novos recursos no dataframe customer_data
customer_data = pd.merge(customer_data, seasonal_buying_patterns, on='CustomerID')
customer_data = pd.merge(customer_data, spending_trends, on='CustomerID')

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#    CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0     12347.0                         2                   7
# 1     12348.0                        75                   4
# 2     12349.0                        18                   1
# 3     12350.0                       310                   1
# 4     12352.0                        36                   7
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458      4310.00                 615.714286
# 1                      2332      1437.24                 359.310000
# 2                       630      1457.55                1457.550000
# 3                       196       294.40                 294.400000
# 4                       526      1385.74                 197.962857
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                        103                        2.016575            1
# ...

# %%
#Alterando o tipo de dados de 'CustomerID' para string, pois é um identificador único e não é usado em operações matemáticas
customer_data['CustomerID'] = customer_data['CustomerID'].astype(str)

#Converta tipos de dados de colunas em tipos ideais
customer_data = customer_data.convert_dtypes()
customer_data.head(10)
# Out:
#   CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0    12347.0                         2                   7
# 1    12348.0                        75                   4
# 2    12349.0                        18                   1
# 3    12350.0                       310                   1
# 4    12352.0                        36                   7
# 5    12353.0                       204                   1
# 6    12354.0                       232                   1
# 7    12355.0                       214                   1
# 8    12356.0                        22                   3
# 9    12357.0                        33                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458       4310.0                 615.714286
# 1                      2332      1437.24                     359.31
# 2                       630      1457.55                    1457.55
# ...

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4261 entries, 0 to 4260
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CustomerID                      4261 non-null   string
#  1   Days_Since_Last_Purchase        4261 non-null   Int64
#  2   Total_Transactions              4261 non-null   Int64
#  3   Total_Products_Purchased        4261 non-null   Int64
#  4   Total_Spend                     4261 non-null   Float64
#  5   Average_Transaction_Value       4261 non-null   Float64
#  6   Unique_Products_Purchased       4261 non-null   Int64
#  7   Average_Days_Between_Purchases  4261 non-null   Float64
#  8   Day_Of_Week                     4261 non-null   Int64
#  9   Hour                            4261 non-null   Int64
#  10  Is_UK                           4261 non-null   Int64
#  11  Monthly_Spending_Mean           4261 non-null   Float64
# ...

# %%
#Inicializando o modelo IsolationForest com parâmetro de contaminação de 0,05
model = IsolationForest(contamination=0.05, random_state=0)

#Ajustando o modelo em nosso conjunto de dados (convertendo DataFrame em NumPy para evitar aviso)
customer_data['Outlier_Scores'] = model.fit_predict(customer_data.iloc[:, 1:].to_numpy())

#Criando uma nova coluna para identificar valores discrepantes (1 para valores discrepantes e -1 para valores discrepantes)
customer_data['Is_Outlier'] = [1 if x == -1 else 0 for x in customer_data['Outlier_Scores']]

#Exibe as primeiras linhas do dataframe customer_data
customer_data.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0    12347.0                         2                   7
# 1    12348.0                        75                   4
# 2    12349.0                        18                   1
# 3    12350.0                       310                   1
# 4    12352.0                        36                   7
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458       4310.0                 615.714286
# 1                      2332      1437.24                     359.31
# 2                       630      1457.55                    1457.55
# 3                       196        294.4                      294.4
# 4                       526      1385.74                 197.962857
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                        103                        2.016575            1
# ...

# %%
#Calcule a porcentagem de inliers e outliers
outlier_percentage = customer_data['Is_Outlier'].value_counts(normalize=True) * 100

#Plotando a porcentagem de inliers e outliers
plt.figure(figsize=(12, 4))
outlier_percentage.plot(kind='barh', color='blue')

#Adicionando os rótulos de porcentagem nas barras
for index, value in enumerate(outlier_percentage):
    plt.text(value, index, f'{value:.2f}%', fontsize=15)

plt.title('Porcentagem de Inliers e Outliers')
plt.xticks(ticks=np.arange(0, 115, 5))
plt.xlabel('Porcentagem (%)')
plt.ylabel('É Outlier')
plt.gca().invert_yaxis()
plt.show()

# %%
#Separe os outliers para análise
outliers_data = customer_data[customer_data['Is_Outlier'] == 1]

#Remova os valores discrepantes do conjunto de dados principal
customer_data_cleaned = customer_data[customer_data['Is_Outlier'] == 0]

#Elimine as colunas 'Outlier_Scores' e 'Is_Outlier'
customer_data_cleaned = customer_data_cleaned.drop(columns=['Outlier_Scores', 'Is_Outlier'])

#Redefinir o índice dos dados limpos
customer_data_cleaned.reset_index(drop=True, inplace=True)

# %%
customer_data_cleaned.shape[0]
# Out:
# 4048

# %%
#Redefinir estilo de fundo
sns.set_style('whitegrid')

#Calcule a matriz de correlação excluindo a coluna 'CustomerID'
corr = customer_data_cleaned.drop(columns=['CustomerID']).corr()

#Defina um mapa de cores personalizado
colors = ['blue', 'red', 'white', 'green', '#ff6200']
my_cmap = LinearSegmentedColormap.from_list('custom_map', colors, N=256)

#Crie uma máscara para mostrar apenas o triângulo inferior da matriz (já que está espelhado em torno de sua
#canto superior esquerdo para diagonal inferior direito)
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, k=1)] = True

#Plot o heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr, mask=mask, cmap=my_cmap, annot=True, center=0, fmt='.2f', linewidths=2)
plt.title('Matriz de correlação', fontsize=14)
plt.show()

# %%
#Inicialize o StandardScaler
scaler = StandardScaler()

#Lista de colunas que não precisam ser dimensionadas
columns_to_exclude = ['CustomerID', 'Is_UK', 'Day_Of_Week']

#Lista de colunas que precisam ser dimensionadas
columns_to_scale = customer_data_cleaned.columns.difference(columns_to_exclude)

#Copie o conjunto de dados limpo
customer_data_scaled = customer_data_cleaned.copy()

#Aplicando o escalonador às colunas necessárias no conjunto de dados
customer_data_scaled[columns_to_scale] = scaler.fit_transform(customer_data_scaled[columns_to_scale])

#Exibe as primeiras linhas dos dados dimensionados
customer_data_scaled.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0    12347.0                 -0.909898            0.885119
# 1    12350.0                  2.202677           -0.671337
# 2    12352.0                 -0.566302            0.885119
# 3    12353.0                  1.131466           -0.671337
# 4    12354.0                  1.414427           -0.671337
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                  1.908080     2.163930                   1.268243
# 1                 -0.546954    -0.600431                  -0.134642
# 2                 -0.188793     0.150854                  -0.555695
# 3                 -0.737974    -0.741829                  -1.031436
# 4                 -0.184451    -0.060032                   3.292734
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                   0.776610                       -0.117062            1
# ...

# %% [markdown]
# #Etapa 03) Selecione um algoritmo de clusterização

# %%
#Definindo CustomerID como coluna de índice
customer_data_scaled.set_index('CustomerID', inplace=True)

#Aplicar PCA
pca = PCA().fit(customer_data_scaled)

#Calcule a Soma Cumulativa da Variância Explicada
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

#Defina o valor k ideal (com base em nossa análise, podemos escolher 6)
optimal_k = 6

#Definir estilo de enredo marítimo
sns.set(rc={'axes.facecolor': '#fcf0dc'}, style='darkgrid')

#Plotar a variância explicada cumulativa em relação ao número de componentes
plt.figure(figsize=(20, 10))


#Gráfico de barras para a variação explicada de cada componente
barplot = sns.barplot(x=list(range(1, len(cumulative_explained_variance) + 1)),
                      y=explained_variance_ratio,
                      color='#fcc36d',
                      alpha=0.8)

#Gráfico de linha para a variação cumulativa explicada
lineplot, = plt.plot(range(0, len(cumulative_explained_variance)), cumulative_explained_variance,
                     marker='o', linestyle='--', color='#ff6200', linewidth=2)

#Plot linha de valor k ideal
optimal_k_line = plt.axvline(optimal_k - 1, color='red', linestyle='--', label=f'Optimal k value = {optimal_k}')

#Definir rótulos e título
plt.xlabel('Número de componentes', fontsize=14)
plt.ylabel('Variância explicada', fontsize=14)
plt.title('Variância cumulativa vs. número de componentes', fontsize=18)


#Customize ticks and legend
plt.xticks(range(0, len(cumulative_explained_variance)))
plt.legend(handles=[barplot.patches[0], lineplot, optimal_k_line],
           labels=['Variância explicada de cada componente', 'Variância explicada cumulativa', f'Valor k ideal = {optimal_k}'],
           loc=(0.62, 0.1),
           frameon=True,
           framealpha=1.0,
           edgecolor='#ff6200')

#Display the variance values for both graphs on the plots
x_offset = -0.3
y_offset = 0.01
for i, (ev_ratio, cum_ev_ratio) in enumerate(zip(explained_variance_ratio, cumulative_explained_variance)):
    plt.text(i, ev_ratio, f'{ev_ratio:.2f}', ha='center', va='bottom', fontsize=10)
    if i > 0:
        plt.text(i + x_offset, cum_ev_ratio + y_offset, f'{cum_ev_ratio:.2f}', ha='center', va='bottom', fontsize=10)

plt.grid(axis='both')
plt.show()

# %%
#Criando um objeto PCA com 6 componentes
pca = PCA(n_components=6)

#Ajustando e transformando os dados originais para o novo dataframe PCA
customer_data_pca = pca.fit_transform(customer_data_scaled)

#Criando um novo dataframe a partir do dataframe PCA, com colunas rotuladas como PC1, PC2, etc.
customer_data_pca = pd.DataFrame(customer_data_pca, columns=['PC'+str(i+1) for i in range(pca.n_components_)])

#Adicionando o índice CustomerID de volta ao novo dataframe PCA
customer_data_pca.index = customer_data_scaled.index

# %%
#Exibindo o dataframe resultante com base nos PCs
customer_data_pca.head()
# Out:
#                  PC1       PC2       PC3       PC4       PC5       PC6
# CustomerID
# 12347.0     3.752680  1.615230  0.144979 -0.440564  0.035274  0.551141
# 12350.0    -1.900294  0.471807  0.874058 -1.398483  0.007220  0.111534
# 12352.0     0.272324  1.481340 -0.968660 -0.598554 -0.058826  0.432047
# 12353.0    -2.345515 -0.615388 -0.293796 -1.621681 -0.093615  0.609921
# 12354.0     0.777682 -0.197592  4.297716  0.094498  0.503802  0.326236

# %%
#Defina uma função para destacar os 3 principais valores absolutos em cada coluna de um dataframe
def highlight_top3(column):
    top3 = column.abs().nlargest(3).index
    return ['background-color:  #f1d47e' if i in top3 else '' for i in column.index]

#Crie o componente PCA DataFrame e aplique a função de destaque
pc_df = pd.DataFrame(pca.components_.T, columns=['PC{}'.format(i+1) for i in range(pca.n_components_)],
                     index=customer_data_scaled.columns)

pc_df.style.apply(highlight_top3, axis=0)
# Out:
# <style type="text/css">
# #T_3922c_row0_col5, #T_3922c_row1_col0, #T_3922c_row1_col2, #T_3922c_row2_col0, #T_3922c_row3_col0, #T_3922c_row4_col2, #T_3922c_row4_col4, #T_3922c_row5_col1, #T_3922c_row5_col3, #T_3922c_row6_col3, #T_3922c_row6_col5, #T_3922c_row7_col1, #T_3922c_row8_col1, #T_3922c_row8_col3, #T_3922c_row8_col5, #T_3922c_row10_col2, #T_3922c_row11_col4, #T_3922c_row12_col4 {
#   background-color: #f1d47e;
# }
# </style>
# <table id="T_3922c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3922c_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_3922c_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_3922c_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_3922c_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_3922c_level0_col4" class="col_heading level0 col4" >PC5</th>
# ...

# %%
#Instancie o modelo de cluster com os parâmetros especificados
km = KMeans(init='k-means++', n_init=10, max_iter=100, random_state=0)

#Crie uma figura e um eixo com o tamanho desejado
fig, ax = plt.subplots(figsize=(12, 5))

#Instancie o KElbowVisualizer com o modelo e intervalo de valores k e desative o gráfico de tempo
visualizer = KElbowVisualizer(km, k=(2, 15), timings=False, ax=ax)

#Treine os dados ao visualizador
visualizer.fit(customer_data_pca)

#Finalize e renderize a figura
visualizer.show();

# %% [markdown]
# #Etapa 04) Analise os clusters obtidos

# %%
def silhouette_analysis(df, start_k, stop_k, figsize=(15, 16)):
    '''
    Execute a análise Silhouette para uma faixa de valores k e visualize os resultados.
    '''

    #Defina o tamanho da figura
    plt.figure(figsize=figsize)

    #Crie uma grade com (stop_k - start_k + 1) linhas e 2 colunas
    grid = gridspec.GridSpec(stop_k - start_k + 1, 2)

    #Atribuir o primeiro gráfico à primeira linha e a ambas as colunas
    first_plot = plt.subplot(grid[0, :])

    #Primeiro gráfico: pontuações de silhueta para diferentes valores de k
    sns.set_palette(['darkorange'])

    silhouette_scores = []

    #Iterar através do intervalo de valores k
    for k in range(start_k, stop_k + 1):
        km = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=100, random_state=0)
        km.fit(df)
        labels = km.predict(df)
        score = silhouette_score(df, labels)
        silhouette_scores.append(score)

    best_k = start_k + silhouette_scores.index(max(silhouette_scores))

    plt.plot(range(start_k, stop_k + 1), silhouette_scores, marker='o')
    plt.xticks(range(start_k, stop_k + 1))
    plt.xlabel('Número de clusters (k)')
    plt.ylabel('Pontuação da silhueta')
    plt.title('Pontuação média da silhueta para diferentes valores de k', fontsize=15)

    #Adicione o texto do valor k ideal ao gráfico
    optimal_k_text = f'O valor k com a pontuação Silhouette mais alta é: {best_k}'
    plt.text(10, 0.23, optimal_k_text, fontsize=12, verticalalignment='bottom',
             horizontalalignment='left', bbox=dict(facecolor='#fcc36d', edgecolor='#ff6200', boxstyle='round, pad=0.5'))


    #Segundo gráfico (subtrama): Gráficos de silhueta para cada valor k
    colors = sns.color_palette('bright')

    for i in range(start_k, stop_k + 1):
        km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=0)
        row_idx, col_idx = divmod(i - start_k, 2)

        #Atribuir os gráficos à segunda, terceira e quarta linhas
        ax = plt.subplot(grid[row_idx + 1, col_idx])

        visualizer = SilhouetteVisualizer(km, colors=colors, ax=ax)
        visualizer.fit(df)

        #Adicione o texto da pontuação da Silhouette ao gráfico
        score = silhouette_score(df, km.labels_)
        ax.text(0.97, 0.02, f'Pontuação da silhueta: {score:.2f}', fontsize=12, \
                ha='right', transform=ax.transAxes, color='red')

        ax.set_title(f'Gráfico de silhueta para {i} Clusters', fontsize=15)

    plt.tight_layout()
    plt.show()

# %%
silhouette_analysis(customer_data_pca, 3, 12, figsize=(20, 50))

# %%
#Apply KMeans clustering using the optimal k
kmeans = KMeans(n_clusters=3, init='k-means++', n_init=10, max_iter=100, random_state=0)
kmeans.fit(customer_data_pca)

#Get the frequency of each cluster
cluster_frequencies = Counter(kmeans.labels_)

#Create a mapping from old labels to new labels based on frequency
label_mapping = {label: new_label for new_label, (label, _) in
                 enumerate(cluster_frequencies.most_common())}

#Reverse the mapping to assign labels as per your criteria
label_mapping = {v: k for k, v in {2: 1, 1: 0, 0: 2}.items()}

#Apply the mapping to get the new labels
new_labels = np.array([label_mapping[label] for label in kmeans.labels_])

#Append the new cluster labels back to the original dataset
customer_data_cleaned['cluster'] = new_labels

#Append the new cluster labels to the PCA version of the dataset
customer_data_pca['cluster'] = new_labels

# %%
#Display the first few rows of the original dataframe
customer_data_cleaned.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  Total_Transactions  \
# 0    12347.0                         2                   7
# 1    12350.0                       310                   1
# 2    12352.0                        36                   7
# 3    12353.0                       204                   1
# 4    12354.0                       232                   1
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                      2458       4310.0                 615.714286
# 1                       196        294.4                      294.4
# 2                       526      1385.74                 197.962857
# 3                        20         89.0                       89.0
# 4                       530       1079.4                     1079.4
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# 0                        103                        2.016575            1
# ...

# %%
#Configurando o esquema de cores dos clusters (ordem RGB)
colors = ['#e8000b', '#1ac938', '#023eff']

# %%
#Crie quadros de dados separados para cada cluster
cluster_0 = customer_data_pca[customer_data_pca['cluster'] == 0]
cluster_1 = customer_data_pca[customer_data_pca['cluster'] == 1]
cluster_2 = customer_data_pca[customer_data_pca['cluster'] == 2]

#Crie um gráfico de dispersão 3D
fig = go.Figure()

#Adicione pontos de dados para cada cluster separadamente e especifique a cor
fig.add_trace(go.Scatter3d(x=cluster_0['PC1'], y=cluster_0['PC2'], z=cluster_0['PC3'],
                           mode='markers', marker=dict(color=colors[0], size=5, opacity=0.4), name='Cluster 0'))
fig.add_trace(go.Scatter3d(x=cluster_1['PC1'], y=cluster_1['PC2'], z=cluster_1['PC3'],
                           mode='markers', marker=dict(color=colors[1], size=5, opacity=0.4), name='Cluster 1'))
fig.add_trace(go.Scatter3d(x=cluster_2['PC1'], y=cluster_2['PC2'], z=cluster_2['PC3'],
                           mode='markers', marker=dict(color=colors[2], size=5, opacity=0.4), name='Cluster 2'))

#Defina o título e os detalhes do layout
fig.update_layout(
    title=dict(text='Visualização 3D de Clusters de Clientes no Espaço PCA', x=0.5),
    scene=dict(
        xaxis=dict(backgroundcolor='#fcf0dc', gridcolor='white', title='PC1'),
        yaxis=dict(backgroundcolor='#fcf0dc', gridcolor='white', title='PC2'),
        zaxis=dict(backgroundcolor='#fcf0dc', gridcolor='white', title='PC3'),
    ),
    width=900,
    height=800
)

#Mostre o plot
fig.show()
# Out:
# <div>                            <div id="9879d3af-1912-4286-8ab6-94b49a42b893" class="plotly-graph-div" style="height:400px; width:450px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9879d3af-1912-4286-8ab6-94b49a42b893")) {                    Plotly.newPlot(                        "9879d3af-1912-4286-8ab6-94b49a42b893",                        [{"marker":{"color":"#e8000b","opacity":0.4,"size":5},"mode":"markers","name":"Cluster 0","x":[-2.3455145528692127,0.7776817845602786,-2.195702625466361,0.839039036830489,-1.3377506123815552,1.6572742809746273,-0.3153323292050588,0.5822430654377282,-2.2304906892279504,-1.0861483015955427,-1.3214785614630042,-0.6555471328329366,-0.19231213146688672,-0.2904884308885048,-0.8101709755878714,-0.7902577192569535,0.15372553661957433,-0.8735328438618406,-1.54829674916979
# ...

# %%
#Calcule a porcentagem de clientes em cada cluster
cluster_percentage = (customer_data_pca['cluster'].value_counts(normalize=True) * 100).reset_index()
cluster_percentage.columns = ['Cluster', 'Percentage']
cluster_percentage.sort_values(by='Cluster', inplace=True)

#Crie um gráfico de barras horizontais
plt.figure(figsize=(10, 4))
sns.barplot(x='Percentage', y='Cluster', data=cluster_percentage, orient='h', palette=colors)

#Adicionando porcentagens nas barras
for index, value in enumerate(cluster_percentage['Percentage']):
    plt.text(value+0.5, index, f'{value:.2f}%')

plt.title('Distribuição de clientes entre clusters', fontsize=14)
plt.xticks(ticks=np.arange(0, 50, 5))
plt.xlabel('Porcentagem (%)')

#Mostre o plot
plt.show()

# %%
#Calcula o número de clientes
num_observations = len(customer_data_pca)

#Separe os recursos e os rótulos do cluster
X = customer_data_pca.drop('cluster', axis=1)
clusters = customer_data_pca['cluster']

#Compute as métricas
sil_score = silhouette_score(X, clusters)
calinski_score = calinski_harabasz_score(X, clusters)
davies_score = davies_bouldin_score(X, clusters)

#Crie uma tabela para exibir as métricas e o número de observações
table_data = [
    ['Number of Observations', num_observations],
    ['Silhouette Score', sil_score],
    ['Calinski Harabasz Score', calinski_score],
    ['Davies Bouldin Score', davies_score]
]

#Printa a table
print(tabulate(table_data, headers=['Metric', 'Value'], tablefmt='pretty'))
# Out:
# +-------------------------+---------------------+
# |         Metric          |        Value        |
# +-------------------------+---------------------+
# | Number of Observations  |        4048         |
# |    Silhouette Score     | 0.24412612813741177 |
# | Calinski Harabasz Score | 1303.2533865286207  |
# |  Davies Bouldin Score   | 1.3418157168877218  |
# +-------------------------+---------------------+

# %%
#Definindo a coluna 'CustomerID' como índice e atribuindo-a a um novo dataframe
df_customer = customer_data_cleaned.set_index('CustomerID')

#Padronize os dados (excluindo a coluna do cluster)
scaler = StandardScaler()
df_customer_standardized = scaler.fit_transform(df_customer.drop(columns=['cluster'], axis=1))

#Crie um novo dataframe com valores padronizados e adicione a coluna do cluster novamente
df_customer_standardized = pd.DataFrame(df_customer_standardized, columns=df_customer.columns[:-1], index=df_customer.index)
df_customer_standardized['cluster'] = df_customer['cluster']

#Calcule os centróides de cada cluster
cluster_centroids = df_customer_standardized.groupby('cluster').mean()

#Função para criar um gráfico de radar
def create_radar_chart(ax, angles, data, color, cluster):
#Plot os dados e preencha a área
    ax.fill(angles, data, color=color, alpha=0.4)
    ax.plot(angles, data, color=color, linewidth=2, linestyle='solid')

#Adicione um título
    ax.set_title(f'Cluster {cluster}', size=20, color=color, y=1.1)

#Definir dados
labels=np.array(cluster_centroids.columns)
num_vars = len(labels)

#Calcula o ângulo de cada eixo
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

#O gráfico é circular, então precisamos 'completar o loop' e anexar o início ao fim
labels = np.concatenate((labels, [labels[0]]))
angles += angles[:1]

#Inicialize a figura
fig, ax = plt.subplots(figsize=(20, 10), subplot_kw=dict(polar=True), nrows=1, ncols=3)

#Criar gráfico de radar para cada cluster
for i, color in enumerate(colors):
    data = cluster_centroids.loc[i].tolist()
    data += data[:1]  #Complete o loop
    create_radar_chart(ax[i], angles, data, color, i)

#Adicionar dados de entrada
ax[0].set_xticks(angles[:-1])
ax[0].set_xticklabels(labels[:-1])

ax[1].set_xticks(angles[:-1])
ax[1].set_xticklabels(labels[:-1])

ax[2].set_xticks(angles[:-1])
ax[2].set_xticklabels(labels[:-1])

#Adicione uma grade
ax[0].grid(color='grey', linewidth=0.5)

#Exibir o plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #Etapa 05) Interpretação dos resultados obtidos

# %% [markdown]
# Clientes do Grupo 0 (Gráfico Vermelho):
#
# Tipo: Compradores Ocasionais que Preferem Comprar nos Fins de Semana.
#
# Este grupo de clientes tende a gastar quantias menores, realizando compras menos frequentes e adquirindo uma quantidade reduzida de produtos. Sua preferência por compras nos fins de semana é evidente, conforme refletido pelo alto volume de compras nesses dias. Os gastos desses clientes tendem a ser consistentes, porém, em níveis baixos, com pouca variação de mês para mês. Além disso, a taxa de cancelamento de pedidos é baixa, e quando fazem compras, geralmente gastam menos em cada transação.

# %% [markdown]
# Cluster 1 (Gráfico Verde):
#
# Perfil: Compradores Ocasionais com Tendência a Gastos Elevados
#
# Os membros deste grupo apresentam um nível de gastos moderado, mas suas compras não ocorrem com muita frequência, conforme indicado pelos longos intervalos entre compras (Dias Desde a Última Compra e Média de Dias Entre Compras). Destacam-se por sua tendência a gastar cada vez mais ao longo do tempo. Esses clientes têm preferência por fazer compras no final do dia, como evidenciado pelo alto valor na variável "Hora," e a maioria deles reside no Reino Unido. Em relação aos cancelamentos, tendem a cancelar um número moderado de transações, apresentando uma taxa média de cancelamento. O valor médio das transações é relativamente alto, o que indica que, quando fazem compras, costumam gastar quantias consideráveis.

# %% [markdown]
# Cluster 2 (Gráfico Azul):
#
# 🎯 Perfil: Compradores Frequentes com Gastos Elevados e Taxa de Cancelamentos Elevada
#
# Os integrantes deste grupo são conhecidos por serem gastadores generosos, apresentando um gasto total bastante significativo e uma predileção por uma ampla variedade de produtos exclusivos. Eles realizam transações de forma frequente, no entanto, também apresentam uma taxa consideravelmente alta de cancelamentos. Esses clientes tendem a efetuar compras com pouca antecedência (indicado por um baixo valor de "Hora"). Seus gastos mensais exibem uma notável variação, sugerindo que seus padrões de despesas podem ser menos previsíveis em comparação com outros grupos. Apesar de seus gastos substanciais, eles exibem uma tendência a uma diminuição gradual nos gastos, o que pode indicar que seus níveis elevados de gastos estão diminuindo ao longo do tempo.

# %% [markdown]
# Na fase final deste projeto, estou atualmente envolvido no desenvolvimento de um sistema de recomendação com o objetivo de aprimorar a experiência de compra online. Esse sistema será responsável por sugerir produtos aos clientes com base nos padrões de compra de seus respectivos grupos.
#
# No estágio inicial do projeto, durante a preparação dos dados dos clientes, identifiquei uma pequena parcela (5%) de clientes que se destacam e isolei esses dados em um conjunto separado denominado "conjunto de dados de outliers".
#
# Agora, estou direcionando minha atenção para os 95% principais do grupo de clientes. Estou analisando os dados depurados desses clientes para identificar os produtos mais populares em cada grupo. Utilizando essas informações, o sistema criará recomendações personalizadas para cada cliente, sugerindo os três produtos mais populares dentro do seu grupo, desde que esses itens ainda não tenham sido adquiridos. Esse processo não apenas contribui para a formulação de estratégias de marketing direcionadas, mas também aprimora a experiência de compra individual, o que, por sua vez, pode impulsionar as vendas.
#
# No que diz respeito ao grupo de clientes destacados (outliers), estou considerando adotar uma abordagem inicial mais simples, como a recomendação de produtos aleatórios, como ponto de partida para envolvê-los e obter um entendimento mais profundo de suas preferências.
