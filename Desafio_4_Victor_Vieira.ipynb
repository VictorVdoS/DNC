# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorVdoS/DNC/blob/main/Desafio_4_Victor_Vieira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio 4: Construindo um modelo de Regressão para marketing:

# %% [markdown]
# ### Autor: [Victor Vieira dos Santos](https://github.com/VictorVdoS)

# %% [markdown]
# # **Contexto - Introdução**
# Uma empresa está investindo mensalmente em plataformas de publicidade online,
# como Youtube, Facebook e newspaper, para a prospecção de leads (pessoas
# interessadas em seus produtos). A fim de acompanhar o desempenho desses
# investimentos, a empresa registra todos os gastos com publicidade e todos os retornos
# de vendas gerados a partir desses investimentos.
# Para entender melhor a relação entre as variáveis presentes nesses registros e
# identificar os fatores que mais impactam na geração de leads, a empresa solicitou a
# análise de um especialista em dados. Além disso, a empresa busca criar um
# modelo de predição de valores para estimar o retorno de vendas que pode ser gerado
# a partir de um determinado investimento em publicidade.

# %% [markdown]
# ## **Sobre os dados**
# A tabela contém informações dos investimentos feitos pelo youtube, facebook,
# newspaper e também a quantidade de cada.
#
# Coluna      | Descrição
# youtube     | Investimento youtube
# facebook    | Investimento facebook
# newspaper   | Investimento newspaper
# sales       | Valor das vendas

# %% [markdown]
# ## **Contexto - Como começar?**
# Comece baixando o arquivo csv. disponibilizado no início desta página. Feito isto,
# busque tratar e interpretar os dados que receberão, eles serão essenciais para a
# construção das próximas etapas.
# 1. Importe o dataset para o colab, utilizando uma biblioteca de manipulação de dados
# 2. Entenda os dados que está visualizando! Para isso, explore as informações das
# variáveis presentes no dataset para identificar possíveis inconsistências, como
# valores ausentes, dados duplicados ou outliers.
# 3. Faça uma análise descritiva das variáveis
# 4. Entenda os dados com a análise exploratória. Nesta etapa do desafio, você pode
# utilizar gráficos e visualizações para identificar padrões, relações e tendências
# entre as variáveis e investigar possíveis correlações.
# 5. Realize a montagem do modelo de regressão para construir um modelo que seja
# capaz de estimar o retorno de vendas a partir de um determinado investimento.
# Utilize também dos materiais complementares para te guiar neste desafio!
# Python Graph Gallery → Repositório com o passo a passo de como gerar gráficos
# utilizando as principais bibliotecas de Python
# SciKit Learn → Documentação com os principais modelos utilizados para
# clusterização

# %% [markdown]
# # **Etapas de Desenvolvimento**
# Para te ajudar nesse processo, detalhar o processo nas etapas a seguir:

# %% [markdown]
# ## **Etapa 01) Análise Descritiva**
# Esta etapa consiste em explorar os dados do dataset para compreender melhor as
# variáveis e identificar problemas. Para isso, é recomendado utilizar a biblioteca
# Pandas para importar e manipular os dados e realizar cálculos estatísticos, além das
# bibliotecas de visualização.
# É importante investigar o tipo de dado em cada variável, os valores e a distribuição dos
# dados. Ao final, espera-se ter uma interpretação sólida dos dados para avançar para a
# próxima etapa.
# 💡 Dica: Utilize a biblioteca Pandas e bibliotecas de visualização de dados para
# entender como seu dataset está.

# %% [markdown]
# ## **Etapa 02) Análise Exploratória**
# Neta etapa iremos explorar mais a fundo os dados, identificando relações entre as
# variáveis e descobrindo padrões relevantes. Para isso, utilize técnicas de
# visualização de dados e análises estatísticas, buscando possíveis correlações e
# identificando possíveis outliers ou desvios da normalidade.
# 💡 Dica: Análise a correlação dos dados e a distribuição dos mesmos

# %% [markdown]
# ## **Etapa 03) Modelagem**
# Para esta etapa, deve-se construir um modelo simples de regressão que permita a
# previsão solicitada pela empresa, com base nos dados disponíveis. Para isto, importe
# as bibliotecas necessárias e carregue os conjuntos de dados para iniciar a sua
# construção!
# 💡 Dica: Utilize as técnicas ensinadas para a criação de um modelo de
# regressão simples utilizando a biblioteca sklearn.

# %% [markdown]
# ## **Etapa 04) Calculando predição**
# Para concluirmos a demanda solicitada pela empresa, iremos aplicar o modelo de
# regressão construído nas etapas anteriores para realizar as previsões de retorno de
# vendas que pode ser gerado a partir de um determinado investimento em publicidade e
# assim, poderemos apresentá-lo a empresa.
# Através dessas previsões, poderemos avaliar o impacto dos diferentes níveis de
# investimento em marketing nas vendas, auxiliando na tomada de decisões e na
# definição de estratégias de negócio.
# 💡 Dica: Utilize os conhecimentos aprendidos para calcular o valor de vendas
# com base nos investimentos em marketing. Utilize técnicas e ferramentas de
# análise de dados com Python.

# %% [markdown]
# # Preparativos

# %% [markdown]
# Antes de prosseguir, realize o download da base de dado neste [link](https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fwww.notion.so%2Fsigned%2Fhttps%253A%252F%252Fs3-us-west-2.amazonaws.com%252Fsecure.notion-static.com%252F6acf00f3-d13e-45bf-8b24-ff63a6c85bf4%252FMKT.csv%3Ftable%3Dblock%26id%3D33fadfe0-8181-4f53-8a1e-8479490c19ff%26spaceId%3D6a055055-52ec-4ebb-a697-63027c951344%26userId%3Dc0845f00-59fb-4a0f-bb4a-c1e2314cd202%26cache%3Dv2)

# %% [markdown]
# Em seguida siga os passos descritos abaixo

# %% [markdown]
# 1° Instale a bliblioteca abaixo

# %%
#bibliotecas
# %pip install plotly

# %% [markdown]
# 2° Realize a importação das bibliotecas e pacotes

# %%
#Importando Bibliotecas
from google.colab import files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# 3° realize o upload do arquivo

# %%
#Upload do arquivo
dataset = files.upload()

# %% [markdown]
# # Estudando os dados

# %% [markdown]
# Analisando os primeiros registros

# %%
base_mkt = pd.read_csv('MKT.csv', sep=',')
base_mkt.head(10)
# Out:
#    youtube  facebook  newspaper  sales
# 0    84.72     19.20      48.96  12.60
# 1   351.48     33.96      51.84  25.68
# 2   135.48     20.88      46.32  14.28
# 3   116.64      1.80      36.00  11.52
# 4   318.72     24.00       0.36  20.88
# 5   114.84      1.68       8.88  11.40
# 6   348.84      4.92      10.20  15.36
# 7   320.28     52.56       6.00  30.48
# 8    89.64     59.28      54.84  17.64
# 9    51.72     32.04      42.12  12.12

# %% [markdown]
# Analisando as distribuições dos dados

# %%
base_mkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB

# %% [markdown]
# Analisando as variáveis

# %%
round(base_mkt.describe(),2)
# Out:
#        youtube  facebook  newspaper   sales
# count   171.00    171.00     171.00  171.00
# mean    178.02     27.67      35.24   16.92
# std     102.45     17.91      24.90    6.31
# min       0.84      0.00       0.36    1.92
# 25%      91.08     11.70      13.74   12.54
# 50%     179.76     26.76      31.08   15.48
# 75%     262.98     43.68      50.88   20.82
# max     355.68     59.52     121.08   32.40

# %% [markdown]
# # Entendendo a posição total de cada elemento

# %%
#Lendo os dados
base_total = pd.DataFrame({'Categoria': base_mkt.columns, 'Total': base_mkt.sum()})
base_total.reset_index(inplace=True)
base_total = base_total[['Categoria', 'Total']]
base_total_sorted = base_total.sort_values(by='Total', ascending=False)
base_total_sorted
# Out:
#    Categoria     Total
# 0    youtube  30441.60
# 2  newspaper   6026.04
# 1   facebook   4731.84
# 3      sales   2893.80

# %% [markdown]
# # Montando a visualização dos dados

# %% [markdown]
# Comparativo de categoria agrupado

# %%
#Histograma dos dados.
sns.histplot(data=base_mkt, x='youtube', color='red', element='step')
sns.histplot(data=base_mkt, x='newspaper', color='gray', element='step')
sns.histplot(data=base_mkt, x='facebook', color='blue', element='step')
sns.histplot(data=base_mkt, x='sales', color='yellow', element='step')
plt.ylabel('Qtd')
plt.xlabel('Valor Investido')
plt.title('Qtd x Investimento');

# %% [markdown]
# Comparativo de catégoria total por coluna

# %%
#Grafico de barras
sns.barplot(data=base_total_sorted, x='Categoria', y='Total');
plt.title('Valor por categoria');

# %% [markdown]
# ## **Resumo do que analisamos**
# Podemos observar que o desvio padrão da categoria "YouTube" é descrepante entre as demais, e que sales que é o valor das vendas muito baixo, ou seja, há uma inconsistencia, pois não tem como o valor das vendas serem mais baixo. O que podemos fazer, pressupor que a base tem um erro em sua tabulação, e que a ordem das colunas está errada, assim, o valor de Sales é Youtube, Youtube é Newspaper, Newspaper é Facebook e Facebook é Sales

# %% [markdown]
# # Ajustando a base

# %%
#Renomeando as colunas
nova_base = base_mkt.rename(columns={'youtube': 'Sales', 'facebook': 'YouTube', 'newspaper': 'Facebook', 'sales': 'Newspaper'})
nova_base.head(10)
# Out:
#     Sales  YouTube  Facebook  Newspaper
# 0   84.72    19.20     48.96      12.60
# 1  351.48    33.96     51.84      25.68
# 2  135.48    20.88     46.32      14.28
# 3  116.64     1.80     36.00      11.52
# 4  318.72    24.00      0.36      20.88
# 5  114.84     1.68      8.88      11.40
# 6  348.84     4.92     10.20      15.36
# 7  320.28    52.56      6.00      30.48
# 8   89.64    59.28     54.84      17.64
# 9   51.72    32.04     42.12      12.12

# %% [markdown]
# # Agora que a base está correta, vamos adicionar uma coluna de Investimento e ROI

# %%
#Criando nova coluna 'investimento' e 'ROI'
nova_base_att = nova_base
nova_base_att['Investimento'] = nova_base_att['YouTube'] + nova_base_att['Facebook'] + nova_base_att['Newspaper']
nova_base_att['ROI'] = round((nova_base_att['Sales'] - nova_base_att['Investimento']) / nova_base_att['Investimento'], 2)
nova_base_att.head()
# Out:
#     Sales  YouTube  Facebook  Newspaper  investimento  Investimento   ROI
# 0   84.72    19.20     48.96      12.60         80.76         80.76  0.05
# 1  351.48    33.96     51.84      25.68        111.48        111.48  2.15
# 2  135.48    20.88     46.32      14.28         81.48         81.48  0.66
# 3  116.64     1.80     36.00      11.52         49.32         49.32  1.36
# 4  318.72    24.00      0.36      20.88         45.24         45.24  6.05

# %%
#Gráfico de linhas por tipo de investimento
multi = nova_base_att[['YouTube', 'Facebook', 'Newspaper']]
plt.figure(figsize=(12,8))
plt.style.use('seaborn-v0_8-dark')
palette = plt.get_cmap('Paired')
num = 0
for col in multi:
  num += 1
  plt.subplot(3, 1, num)
  for i in multi:
    plt.plot(multi.index, multi[i], marker='', color='red', linewidth=0.8, alpha=0.2)
  plt.plot(multi.index, multi[col], marker='', color=palette(num), linewidth=1.6, alpha=0.9, label=col)
  plt.title(col, loc='center', fontsize=10, fontweight=2, color='black')
plt.show();

# %%
#Gráfico de linhas de total de investimento x vendas
fig, ay = plt.subplots(figsize=(16, 8))
sns.lineplot(data=nova_base_att, x=nova_base_att.index, y='Investimento', color='yellow', label='Investimento')
sns.lineplot(data=nova_base_att, x=nova_base_att.index, y='Sales', color='green', label='Sales')
ay.fill_between(
    nova_base_att.index, nova_base_att['Investimento'], nova_base_att['Sales'],
    where=(nova_base_att['Investimento'] > nova_base_att['Sales']),
    interpolate=True, color='yellow', alpha=0.25
    )
ay.fill_between(
    nova_base_att.index, nova_base_att['Investimento'], nova_base_att['Sales'],
    where=(nova_base_att['Investimento'] < nova_base_att['Sales']),
    interpolate=True, color='green', alpha=0.25
    )
ay.legend()
plt.xlabel('Qtd')
plt.ylabel('Valor')
plt.title('Valor Total de Investimento e Vendas');
plt.show()

# %%
#Analisando a relação entre as colunas
nova_base_att.corr()
# Out:
#                  Sales   YouTube  Facebook  Newspaper  investimento  \
# Sales         1.000000  0.086538  0.110759   0.782030      0.242053
# YouTube       0.086538  1.000000  0.293425   0.602918      0.759873
# Facebook      0.110759  0.293425  1.000000   0.254987      0.831638
# Newspaper     0.782030  0.602918  0.254987   1.000000      0.614250
# investimento  0.242053  0.759873  0.831638   0.614250      1.000000
# Investimento  0.242053  0.759873  0.831638   0.614250      1.000000
# ROI           0.630784 -0.456183 -0.422037   0.160420     -0.462523
#
#               Investimento       ROI
# Sales             0.242053  0.630784
# YouTube           0.759873 -0.456183
# Facebook          0.831638 -0.422037
# Newspaper         0.614250  0.160420
# investimento      1.000000 -0.462523
# Investimento      1.000000 -0.462523
# ROI              -0.462523  1.000000

# %%
#Analisando a relação em gráfico.
sns.pairplot(nova_base_att, x_vars=['YouTube', 'Facebook', 'Newspaper', 'Investimento'], y_vars=['Sales', 'ROI']);

# %%
#Analisando em mapa de calor.
sns.heatmap(nova_base_att.corr(), annot=True);

# %%
sns.histplot(nova_base_att['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# ## Com essas disposições gráficas conseguimos analisar que o canal que mais sofreu impacto nos investimentos visando ROI foi o de Newspaper, mesmo recebendo uma fatia menor da taxa investida.

# %% [markdown]
# # Regressão Linear
# Agroa vamos treinar um modelo e aplicar uma regressão linear simples.

# %%
nova_base_att.columns
# Out:
# Index(['Sales', 'YouTube', 'Facebook', 'Newspaper', 'investimento',
#        'Investimento', 'ROI'],
#       dtype='object')

# %%
#Separando Variaveis X e Y.
X = nova_base_att[['YouTube', 'Facebook', 'Newspaper']]

Y = nova_base_att['Sales']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8, random_state=22)

# %%
# Chamando a regressão e treinando o modelo.
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#TEstando Modelo
modelo_teste = lm.predict(X_test)

# %%
#Analisando.
precisao = r2_score(Y_test, modelo_teste)
print(f'A precisão deste modelo é de {round(precisao*100)}%.')
# Out:
# A precisão deste modelo é de 91%.

# %% [markdown]
# # **Conclusão Final**
# Podemos concluir que utilizando 80% da base para treinamento, conseguimos uma precisão de 91%
#
# Resultado: **SUCESSO**
